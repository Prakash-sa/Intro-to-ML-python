# %% [markdown]
# ## CLASSIFICATION of CREDIT CARD CUSTOMERS with the K-MEANS CLUSTERING

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np
from sklearn.cluster import KMeans
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
card = pd.read_csv("./data/CCGENERAL.csv")

# %%
card.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# ...

# %%
card.describe().T
# Out:
#                                    count         mean          std        min  \
# BALANCE                           8950.0  1564.474828  2081.531879   0.000000
# BALANCE_FREQUENCY                 8950.0     0.877271     0.236904   0.000000
# PURCHASES                         8950.0  1003.204834  2136.634782   0.000000
# ONEOFF_PURCHASES                  8950.0   592.437371  1659.887917   0.000000
# INSTALLMENTS_PURCHASES            8950.0   411.067645   904.338115   0.000000
# CASH_ADVANCE                      8950.0   978.871112  2097.163877   0.000000
# PURCHASES_FREQUENCY               8950.0     0.490351     0.401371   0.000000
# ONEOFF_PURCHASES_FREQUENCY        8950.0     0.202458     0.298336   0.000000
# PURCHASES_INSTALLMENTS_FREQUENCY  8950.0     0.364437     0.397448   0.000000
# CASH_ADVANCE_FREQUENCY            8950.0     0.135144     0.200121   0.000000
# CASH_ADVANCE_TRX                  8950.0     3.248827     6.824647   0.000000
# ...

# %%
# Get the column Stats.
card.isna().sum()
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64

# %%
card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
# ...

# %%
mean_value=card['CREDIT_LIMIT'].mean()
card['CREDIT_LIMIT']=card['CREDIT_LIMIT'].fillna(mean_value)

# %%
mean_value=card['MINIMUM_PAYMENTS'].mean()
card['MINIMUM_PAYMENTS']=card['MINIMUM_PAYMENTS'].fillna(mean_value)

# %%
card.isna().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
correlationM= card.corr()

# %%
plt.figure(figsize=(20,10))
sns.heatmap(correlationM,vmin=-1,vmax=1,center=0,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Vizualize Data
#
# Let's visualize how skewed our dataset is.

# %%
plt.figure(figsize=(20,35))
for i, col in enumerate(card.columns):
    if card[col].dtype != 'object':
        ax = plt.subplot(9, 2, i+1)
        sns.kdeplot(card[col], ax=ax)
        plt.xlabel(col)
        
plt.show()

# %% [markdown]
# ### Data Processing

# %%
#  Pre Process or Drop features and columns before building the model.

df = card.drop('CUST_ID', axis=1)
df.head(3)
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                         0.0                          0.083333
# 1                         0.0                          0.000000
# 2                         1.0                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                    0.00                 0              2        1000.0
# ...

# %%
from sklearn.preprocessing import StandardScaler
X = df.values[:,1:]
X = np.nan_to_num(X)
Clus_dataSet = StandardScaler().fit_transform(X)
Clus_dataSet
# Out:
# array([[-0.24943448, -0.42489974, -0.35693402, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.13432467, -0.46955188, -0.35693402, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.51808382, -0.10766823,  0.10888851, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.18547673, -0.40196519, -0.35693402, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.18547673, -0.46955188, -0.35693402, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.88903307,  0.04214581,  0.30173158, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %%
card.shape
# Out:
# (8950, 18)

# %% [markdown]
# ### K-Means Clusturing Model

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=6,random_state=0)
kmeans.fit(df)
# Out:
# KMeans(n_clusters=6, random_state=0)

# %%
Sum_of_squared_distances = []
K = range(1,21)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(df)
    Sum_of_squared_distances.append(km.inertia_)
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %% [markdown]
# *** The Elbow curve depicts sum of squared distances for each point from its respective centroid. Our goal is to check for a K value that has minimum sum of square distance.

# %% [markdown]
# *** We calculate to measure the accuracy or goodness of our clustering technique using Silhouette Coefficient or Silhouette score.

# %%
from sklearn.metrics import silhouette_score, silhouette_samples

for n_clusters in range(2,21):
    km = KMeans (n_clusters=n_clusters)
    preds = km.fit_predict(df)
    centers = km.cluster_centers_

    score = silhouette_score(df, preds, metric='euclidean')
    print ("For n_clusters = {}, silhouette score is {}".format(n_clusters, score))
# Out:
# For n_clusters = 2, silhouette score is 0.5114773214237212
# For n_clusters = 3, silhouette score is 0.4655437166888681
# For n_clusters = 4, silhouette score is 0.39813827225952697
# For n_clusters = 5, silhouette score is 0.4027619591941917
# For n_clusters = 6, silhouette score is 0.4089850423020922
# For n_clusters = 7, silhouette score is 0.3688329862131134
# For n_clusters = 8, silhouette score is 0.38169645950665093
# For n_clusters = 9, silhouette score is 0.3517024526403775
# For n_clusters = 10, silhouette score is 0.35257689233614176
# For n_clusters = 11, silhouette score is 0.3577518082582107
# For n_clusters = 12, silhouette score is 0.33781484684356117
# For n_clusters = 13, silhouette score is 0.3056559997934157
# For n_clusters = 14, silhouette score is 0.28446658232384736
# For n_clusters = 15, silhouette score is 0.25795211635616494
# For n_clusters = 16, silhouette score is 0.25921605472650894
# For n_clusters = 17, silhouette score is 0.29004831506530454
# ...

# %% [markdown]
# ** K=3 has maximum Silhoutte score.
