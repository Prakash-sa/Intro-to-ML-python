# %% [markdown]
# ## Working with Text Data

# %%
#Read Text
with open("./data/ML_ref_Wikipedia.txt", 'r') as fh:  
    descriptions = fh.read().splitlines()
print("Sample course descriptions :", descriptions[:5])
# Out:
# Sample course descriptions : ['Machine learning (ML) is the study of computer algorithms that can improve automatically through experience and by the use of data.[1] It is seen as a part of artificial intelligence. Machine learning algorithms build a model based on sample data, known as training data, in order to make predictions or decisions without being explicitly programmed to do so.[2] Machine learning algorithms are used in a wide variety of applications, such as in medicine, email filtering, speech recognition, and computer vision, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks.[3]', '', 'A subset of machine learning is closely related to computational statistics, which focuses on making predictions using computers; but not all machine learning is statistical learning. The study of mathematical optimization delivers methods, theory and application domains to the field of machine learning. Data mining is a related field of stu
# ...

# %%
### Import nltk (download nltk if not done before)
#Setup stopwords
import nltk
# nltk.download('stopwords')
from nltk.corpus import stopwords

# %%
#setup wordnet for lemmatization
# What is Wordnet? (https://en.wikipedia.org/wiki/WordNet)
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer=...

# %% [markdown]
# ### Preparing Data for Classification - Build a Tfidf Vector

# %%
### Get Tfidf Scores
from sklearn.feature_extraction.text import TfidfVectorizer

#Custom tokenizer that will perform tokenization, stopword removal
#and lemmatization

...
print("\nSample feature names identified : ", vectorizer.get_feature_names()[:25])
print("\nSize of TFIDF matrix : ",tfidf.shape)

# %% [markdown]
# ### Displaying the Wordcloud

# %%
#to install wordcloud - execute "pip install wordcloud" from Anaconda prompt

#read the course descriptions
with open("./data/ML_ref_Wikipedia.txt", 'r') as fh:  
    filedata = fh.read()

#check contents

# Create stopword list:

#Generate wordcloud data
# Out:
# File data sample :  Machine learning (ML) is the study of computer algorithms that can improve automatically through experience and by the use of data.[1] It is seen as a part of artificial intelligence. Machine learning

# %%
import matplotlib.pyplot as mpLib

# %% [markdown]
# ## 01_04 Enhancing Wordcloud

# %%
#Add more words to ignore any unimportant words.

#Redo stop words. Limit number of words  or frequency of occurance
