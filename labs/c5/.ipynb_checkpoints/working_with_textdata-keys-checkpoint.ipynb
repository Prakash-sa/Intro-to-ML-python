# %% [markdown]
# ## Working with Text Data

# %%
#Read Text
with open("./data/ML_ref_Wikipedia.txt", 'r') as fh:  
    descriptions = fh.read().splitlines()
print("Sample course descriptions :", descriptions[:2])
# Out:
# Sample course descriptions : ['Machine learning (ML) is the study of computer algorithms that can improve automatically through experience and by the use of data.[1] It is seen as a part of artificial intelligence. Machine learning algorithms build a model based on sample data, known as training data, in order to make predictions or decisions without being explicitly programmed to do so.[2] Machine learning algorithms are used in a wide variety of applications, such as in medicine, email filtering, speech recognition, and computer vision, where it is difficult or unfeasible to develop conventional algorithms to perform the needed tasks.[3]', '']

# %%
len(descriptions)
# Out:
# 41

# %%
### Import nltk (download nltk if not done before)
#Setup stopwords
import nltk
# nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14280/1541949978.py in <module>
#       1 ### Import nltk (download nltk if not done before)
#       2 #Setup stopwords
# ----> 3 import nltk
#       4 # nltk.download('stopwords')
#       5 from nltk.corpus import stopwords
#
# ModuleNotFoundError: No module named 'nltk'

# %%
#setup wordnet for lemmatization
# What is Wordnet? (https://en.wikipedia.org/wiki/WordNet)
# nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()

# %% [markdown]
# ### Preparing Data for Text Classification

# %%
### Get Tfidf Scores
from sklearn.feature_extraction.text import TfidfVectorizer

#Custom tokenizer that will perform tokenization, stopword removal
#and lemmatization
def customtokenize(str):
    tokens=nltk.word_tokenize(str)
    ntokens = nltk.RegexpTokenizer(r"\w+")
    words = ntokens.tokenize(str)
    nostop = list(filter(lambda token: token not in stopwords.words('english'), words))
    lemmatized=[lemmatizer.lemmatize(word) for word in nostop ]
    return lemmatized

#Generate TFIDF matrix
vectorizer = TfidfVectorizer(tokenizer=customtokenize)
tfidf=vectorizer.fit_transform(descriptions)

print("\nSample feature names identified : ", vectorizer.get_feature_names()[:150])
print("\nSize of TFIDF matrix : ",tfidf.shape)
# Out:
# Sample feature names identified :  ['000', '1', '10', '1980', '1980s', '1990s', '2', '2020', '21', '22', '23', '24', '25', '26', '27', '28', '29', '3', '30', '31', '32', '33', '4', '488', '5', '6', '7', '708', '710', '755', '8', '9', 'abandoned', 'ability', 'academic', 'accomplish', 'according', 'accuracy', 'achieving', 'acquisition', 'across', 'action', 'active', 'actual', 'adopted', 'advanced', 'agent', 'ai', 'algorithm', 'algorithmic', 'also', 'analysis', 'analytics', 'answer', 'application', 'approach', 'arises', 'around', 'artificial', 'assert', 'assign', 'assigned', 'assumption', 'attempted', 'automated', 'automatically', 'available', 'away', 'backpropagation', 'based', 'basic', 'basis', 'biological', 'black', 'borrowed', 'brain', 'breiman', 'build', 'business', 'c', 'call', 'came', 'cannot', 'carry', 'case', 'caused', 'certain', 'challenging', 'chance', 'changed', 'character', 'characterizing', 'classification', 'closely', 'color', 'combined', 'come', 'community', 'computational', 'computer', 'concerned', 'conference', 'confusion', 'connectionism', 'considered', 'continue', 'continued', 'conventional', 'correct', 'correctly', 'create', 'current', 'data', 'database', 'dataset', 'day', 'decision', 'deep', 'delivers', 'determine', 'develop', 'diagnosis', 'difference', 'different', 'difficult', 'digit', 'digital', 'discipline', 'discovery', 'discrepancy', 'distinct', 'distinguished', 'domain', 'dominate', 'draw', 'due', 'early', 'easily', 'ecml', 'effective', 'email', 'emphasis', 'employ', 'employed', 'endeavor', 'environment', 'especially', 'evaluated', 'every', 'example']
#
# Size of TFIDF matrix :  (41, 419)

# %% [markdown]
# ## Displaying the Wordcloud

# %%
#to install wordcloud - execute "pip install wordcloud" from Anaconda prompt

#read the course descriptions
with open("./data/ML_ref_Wikipedia.txt", 'r') as fh:  
    filedata = fh.read()

#check contents
print("File data sample : ", filedata[:200])

# Create stopword list:
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)

#Generate wordcloud data
wordcloud = WordCloud(stopwords=stopwords, max_words=20, background_color="white").generate(filedata)
# Out:
# File data sample :  Machine learning (ML) is the study of computer algorithms that can improve automatically through experience and by the use of data.[1] It is seen as a part of artificial intelligence. Machine learning

# %%
import matplotlib.pyplot as mpLib
mpLib.imshow(wordcloud)
mpLib.axis("on")
mpLib.show()

# %% [markdown]
# ##  Enhancing Wordcloud

# %%
#Add more words to ignore 
stopwords.update(["need","use", "goal", "value"])

#Redo stop words. Limit number of words
wordcloud = WordCloud(stopwords=stopwords, max_words=10, \
                      background_color="azure").generate(filedata)

mpLib.imshow(wordcloud)
mpLib.axis("on")
mpLib.show()
